# %% [markdown]
# 1. go to a website
# 2. seearch for a respective product
# 3. locate review part
# 4. scrap all the dat in local system

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
uClient =uReq(flipkart_url)

# %%
uClient

# %%
flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.5ffd15.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
mainframe = flipkart_html.findAll("div",{"class" : "_1AtVbE col-12-12"})

# %%
len(mainframe)
# Out:
# 30

# %%
for i in mainframe:
    print(i)
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4i
# ...

# %%
del mainframe[0:3]

# %%
box  = mainframe[0]

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a["href"]

# %%
productLink
# Out:
# 'https://www.flipkart.com/apple-iphone-13-starlight-128-gb/p/itmc9604f122ae7f?pid=MOBG6VF5ADKHKXFX&lid=LSTMOBG6VF5ADKHKXFXQGX7PK&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=bccb704e-eccd-447f-80c2-5a2942bdf01f.MOBG6VF5ADKHKXFX.SEARCH&ppt=None&ppn=None&ssid=e2t3wnkb8g0000001691453854341&qH=0b3f45b266a97d70'

# %%
prodRes = requests.get(productLink)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prodRes.encoding = 'utf-8'

# %%
prod_html = bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
reviewframe = prod_html.findAll("div", {'class':"_16PBlm"})

# %%
len(reviewframe)
# Out:
# 11

# %%
for review in reviewframe:
    print(review)
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Excellent</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Too good</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_2e36b734d25b456fa0455ec8b86f2c91.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Aniket Banerjee</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-a6a2eaeb-4048-4ee0-a032-8f3bcd755163"><span>Certifi
# ...

# %%
for i in range(len(reviewframe)-1):
    print(reviewframe[i].div.div.findAll("p",{"class" : "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Aniket Banerjee
# Flipkart Customer
# Shivang Palyal
# Peris Kumar Bhagat
# Badri Bishal  Pratihari
# Pushpita Mayra
# Prasenjit Bar
# Sachin Saini
# Sivam Ray
# Ajay Kr

# %%
reviewframe[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Excellent</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Too good</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_2e36b734d25b456fa0455ec8b86f2c91.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">Aniket Banerjee</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-a6a2eaeb-4048-4ee0-a032-8f3bcd755163"><span>Certifi
# ...

# %%
reviewframe[0].div.div.div.p.text
# Out:
# 'Excellent'

# %%
for i in range(len(reviewframe)-1):
    print(reviewframe[i].div.div.findAll("p",{"class" : "_2sc7ZR _2V5EHH"})[0].text,)
    print(reviewframe[i].div.div.div.div.text)
    print(reviewframe[i].div.div.div.p.text)
    print(reviewframe[i].div.div.find_all("div", {"class": ''})[0].div.text,'\n')
# Out:
# Aniket Banerjee
# 5
# Excellent
# Too good
#
# Flipkart Customer
# 5
# Terrific
# Happy to have this phone
#
# Shivang Palyal
# 5
# Classy product
# This is awosome .. camera is best . Here some photos i m sharing with you guys ..
#
# Peris Kumar Bhagat
# 5
# Mind-blowing purchase
# Great performance 🥰
#
# Badri Bishal  Pratihari
# 5
# Perfect product!
# Love this phone..... 😍
#
# Pushpita Mayra
# 5
# Must buy!
# Awesome phone Excellent camera quality
#
# Prasenjit Bar
# 4
# Nice product
# Best phone for day to day use and photography/videography.
#
# Sachin Saini
# 4
# Really Nice
# My first I phone ..from a long time android user… apple camera is way ahead  ,.. interface is better than android….overall premium features and feeling. .;but prices way aboveboard
#
# Sivam Ray
# 5
# Mind-blowing purchase
# Camera  is superb 🫡❤️
#
# Ajay Kr
# 5
# Worth every penny
# Awesome camera..I m love  it
